# %% [markdown]
# # Seaborn Visualization on Titanic Dataset

# %% [markdown]
# ## The Data
#
# We will be working with a famous titanic data set.
# We may use this dataset to predict survival rates of passengers.
#
# For now, we'll just focus on the visualization of the data with seaborn:

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('whitegrid')

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.jointplot(x='fare',y='age',data=titanic)

# %%
sns.distplot(titanic['fare'],bins=30,kde=False,color='red')

# %%
sns.boxplot(x='class',y='age',data=titanic,palette='rainbow')

# %%
sns.swarmplot(x='class',y='age',data=titanic,palette='Set2')
# Out:
# c:\python\python38-32\lib\site-packages\seaborn\categorical.py:1311: RuntimeWarning: invalid value encountered in less
#   off_low = points < low_gutter
# c:\python\python38-32\lib\site-packages\seaborn\categorical.py:1315: RuntimeWarning: invalid value encountered in greater
#   off_high = points > high_gutter

# %%
sns.countplot(x='sex',data=titanic)

# %%
sns.heatmap(titanic.corr(),cmap='coolwarm')
plt.title('titanic.corr()')
# Out:
# Text(0.5, 1, 'titanic.corr()')

# %%
g = sns.FacetGrid(data=titanic,col='sex')
g.map(plt.hist,'age')
